# %% [markdown]
# <a href="https://colab.research.google.com/github/pszachew/Delivery-Prediction/blob/master/GTZAN_MUSIC_SPEECH/embedding_mfcc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import sys
drive.mount('/content/gdrive')
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import os
import librosa
import pandas as pd

# %%
directory = ['speech', 'music']

# %%
path_in = "/content/gdrive/MyDrive/Data/GTZAN_music_speech"

# %%
X=[]
label=[]
for direct in directory:
    for file in os.listdir(path_in + "/" + direct):
        src, sr = librosa.load(path_in + '/' + direct + '/' + file)
        mfcc = librosa.feature.mfcc(y=src, sr = sr, n_mfcc=20)
        dmfcc = mfcc[:, 1:] - mfcc[:, :-1]
        ddmfcc = dmfcc[:, 1:] - dmfcc[:, :-1]
        X.append(np.concatenate((np.mean(mfcc, axis=1), np.std(mfcc, axis=1),
                           np.mean(dmfcc, axis=1), np.std(dmfcc, axis=1),
                           np.mean(ddmfcc, axis=1), np.std(ddmfcc, axis=1))
                          , axis=0))
        label.append(direct)

# %%
X_df = pd.DataFrame(X)
X_df
# Out:
#             0           1          2    ...       117       118       119
# 0   -229.321976  108.632256  -7.654047  ...  5.366319  4.971335  5.028266
# 1   -348.617493   98.462204  17.148643  ...  4.895457  4.846707  4.748610
# 2   -225.887238   81.504204 -17.323345  ...  5.126247  5.016128  4.980556
# 3   -256.364258   76.938042  -8.520288  ...  4.697835  4.627471  4.545484
# 4   -237.621323   77.945702  -4.441962  ...  4.651785  4.647558  4.461828
# ..          ...         ...        ...  ...       ...       ...       ...
# 123 -161.884705   77.357368   4.708924  ...  4.383566  4.100072  4.118594
# 124 -109.528641  106.357376 -22.417982  ...  4.433000  4.303867  4.079257
# 125 -165.455170  115.005440   1.115721  ...  5.042150  4.537956  4.472816
# 126 -223.540726  166.325317 -41.890633  ...  4.384827  4.358711  4.208874
# 127 -214.702515  147.740189  -5.034620  ...  4.171959  3.931353  4.215230
#
# [128 rows x 120 columns]

# %%
labels_df = pd.DataFrame(label)

# %%
X_df.to_csv("/content/gdrive/MyDrive/csv_data/GTZAN_speech_music/features_mfcc.csv", index=None, header=None)

# %%
labels_df.to_csv("/content/gdrive/MyDrive/csv_data/GTZAN_speech_music/labels_mfcc.csv", index=None, header=None)
